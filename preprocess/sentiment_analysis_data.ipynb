# %%
import pandas as pd
import numpy as np
from transformers import pipeline
import torch

# %%
def sentiment_analysis(df: pd.DataFrame) -> pd.DataFrame:
    sentiment_analyzer = pipeline("text-classification", model="tabularisai/multilingual-sentiment-analysis")


    def analyze_sentiment(text):
        try:
            result = sentiment_analyzer(text)  # Limit text length for performance
            return result[0]['label']
        except Exception as e:
            #print(f"Error analyzing sentiment for text: {text}\n{e}")
            return "Neutral"

    sentiments = [analyze_sentiment(text) for text in df['text']]
    df['sentiment_score'] = sentiments

    return df

# %%
df = pd.read_csv('/home/eder/projects/big-data-management/Hackathon_GESTDB/data/api_data/comments_data.csv')

# %%
df.tail()
# Out:
#                                id     id_video  \
# 29099  Ugws8zwuN7wYJTv6dpR4AaABAg  cU2dZz18P0c
# 29100  UgzW-5dgfjsjNhSCu_p4AaABAg  cU2dZz18P0c
# 29101  UgwKfm6NsRRPDhhuhaR4AaABAg  cU2dZz18P0c
# 29102  Ugwp8OeNrHcxyLn3Dth4AaABAg  cU2dZz18P0c
# 29103  UgyIGNBx2DkIitc7Bd54AaABAg  cU2dZz18P0c
#
#                                                     text  \
# 29099                   To think these people reproduce!
# 29100  Examples of why people should have to pass a t...
# 29101                  The sun is moving, not the earth.
# 29102                               364 and one quarter.
# 29103                                   365 and 1/4 days
#
#                published_at  like_count  is_possitive
# 29099  2025-10-02T03:41:36Z         0.0             1
# 29100  2025-10-02T01:07:59Z         0.0             0
# 29101  2025-10-01T12:40:57Z         0.0             0
# 29102  2025-10-01T12:38:39Z         0.0             1
# 29103  2025-10-01T05:06:35Z         0.0             0

# %%
sent = sentiment_analysis(df)
# Out:
# Device set to use cuda:0
# Token indices sequence length is longer than the specified maximum sequence length for this model (800 > 512). Running this sequence through the model will result in indexing errors

# %%
sent.tail()
# Out:
#                                id     id_video  \
# 29099  Ugws8zwuN7wYJTv6dpR4AaABAg  cU2dZz18P0c
# 29100  UgzW-5dgfjsjNhSCu_p4AaABAg  cU2dZz18P0c
# 29101  UgwKfm6NsRRPDhhuhaR4AaABAg  cU2dZz18P0c
# 29102  Ugwp8OeNrHcxyLn3Dth4AaABAg  cU2dZz18P0c
# 29103  UgyIGNBx2DkIitc7Bd54AaABAg  cU2dZz18P0c
#
#                                                     text  \
# 29099                   To think these people reproduce!
# 29100  Examples of why people should have to pass a t...
# 29101                  The sun is moving, not the earth.
# 29102                               364 and one quarter.
# 29103                                   365 and 1/4 days
#
#                published_at  like_count  is_possitive sentiment_score
# 29099  2025-10-02T03:41:36Z         0.0             1        Positive
# 29100  2025-10-02T01:07:59Z         0.0             0         Neutral
# 29101  2025-10-01T12:40:57Z         0.0             0         Neutral
# 29102  2025-10-01T12:38:39Z         0.0             1         Neutral
# 29103  2025-10-01T05:06:35Z         0.0             0         Neutral

# %%
# mapping
mapping = {'Very Negative': 1, 'Negative': 2, 'Neutral': 3, 'Positive': 4, 'Very Positive': 5}

# %%
df['sentiment_score'] = df['sentiment_score'].map(mapping)

# %%
sent.tail()
# Out:
#                                id     id_video  \
# 29099  Ugws8zwuN7wYJTv6dpR4AaABAg  cU2dZz18P0c
# 29100  UgzW-5dgfjsjNhSCu_p4AaABAg  cU2dZz18P0c
# 29101  UgwKfm6NsRRPDhhuhaR4AaABAg  cU2dZz18P0c
# 29102  Ugwp8OeNrHcxyLn3Dth4AaABAg  cU2dZz18P0c
# 29103  UgyIGNBx2DkIitc7Bd54AaABAg  cU2dZz18P0c
#
#                                                     text  \
# 29099                   To think these people reproduce!
# 29100  Examples of why people should have to pass a t...
# 29101                  The sun is moving, not the earth.
# 29102                               364 and one quarter.
# 29103                                   365 and 1/4 days
#
#                published_at  like_count  is_possitive  sentiment_score
# 29099  2025-10-02T03:41:36Z         0.0             1                4
# 29100  2025-10-02T01:07:59Z         0.0             0                3
# 29101  2025-10-01T12:40:57Z         0.0             0                3
# 29102  2025-10-01T12:38:39Z         0.0             1                3
# 29103  2025-10-01T05:06:35Z         0.0             0                3

# %%
sent.to_csv('/home/eder/projects/big-data-management/Hackathon_GESTDB/data/api_data/comments_data.csv', index=False)
